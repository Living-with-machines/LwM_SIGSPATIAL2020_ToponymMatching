# %%
from Levenshtein import editops
import pandas as pd
import numpy as np
from itertools import groupby
from operator import itemgetter
from collections import Counter
import unicodedata
import random

# %%
ocrdf = pd.read_csv("ocrTokens.tsv", sep="\t", names=["ocrtext", "humtext"])

# %%
ocrdf.head()
# Out:
#       ocrtext     humtext
# 0  Customlinc  Customline
# 1     Hunlber      Humber
# 2      Gurdon      Gordon
# 3        rort        Fort
# 4      Sydnej      Sydney

# %%
ocrdf.shape
# Out:
# (140313, 2)

# %%
def find_consecutive_ranges(ltrans):
    transchunks = []
    for k, g in groupby(enumerate(ltrans), lambda ix : ix[0] - ix[1]):
        transchunks.append(list(map(itemgetter(1), g)))
    return transchunks

# %%
def capture_transformations(humtext, ocrtext, transformations):
    observed_transformations = []
    
    othtransf = False # False if all transformations are 'replace'
    for t in transformations:
        if not t[0] == 'replace':
            othtransf = True

    # Dictionary of human2ocr transformations, and of ocr2hum transformations
    dHum2OcrTrans = dict()
    dOcr2HumTrans = dict()
    for t in transformations:
        ttype = t[0]
        tcharhum = t[1]
        tcharocr = t[2]
        if tcharhum in dHum2OcrTrans:
            dHum2OcrTrans[tcharhum].append((tcharocr, ttype))
        else:
            dHum2OcrTrans[tcharhum] = [(tcharocr, ttype)]
        if tcharocr in dOcr2HumTrans:
            dOcr2HumTrans[tcharocr].append((tcharhum, ttype))
        else:
            dOcr2HumTrans[tcharocr] = [(tcharhum, ttype)]
        
    # Only 'replace' transformations:
    if othtransf == False:
        humrepls = [t[1] for t in transformations] # Indices replaced in humtext
        ocrrepls = [t[2] for t in transformations] # Indices replaced in ocrtext
        humranges = find_consecutive_ranges(humrepls)
        ocrranges = find_consecutive_ranges(ocrrepls)
        
        for i in range(len(humranges)):
            newhum = ""
            newocr = ""
            for j in range(len(humranges[i])):
                newhum += humtext[humranges[i][j]]
                newocr += ocrtext[ocrranges[i][j]]
            if newhum or newocr:
                observed_transformations.append((newhum, newocr))
    
    # Other transformations too:
    else:
        # If there is a 'delete', we capture it from the ocr2hum dictionary
        for ocr in dOcr2HumTrans:
            newhum = ""
            newocr = ""
            try:
                newocr = ocrtext[ocr]
                if len(dOcr2HumTrans[ocr]) > 1 and any(tr_item[1] == 'delete' for tr_item in dOcr2HumTrans[ocr]):
                    for ch_trans in dOcr2HumTrans[ocr]:
                        newhum += humtext[ch_trans[0]]
                if newhum and newocr:
                    observed_transformations.append((newhum, newocr))
            except IndexError:
                pass
            
        # If there is an 'insert', we capture it from the hum2ocr dictionary    
        for hum in dHum2OcrTrans:
            newhum = ""
            newocr = ""
            try:
                newocr = humtext[hum]
                if len(dHum2OcrTrans[hum]) > 1 and any(tr_item[1] == 'insert' for tr_item in dHum2OcrTrans[hum]):
                    for ch_trans in dHum2OcrTrans[hum]:
                        newhum += ocrtext[ch_trans[0]]
                if newhum and newocr:
                    observed_transformations.append((newhum, newocr))
            except IndexError:
                pass

    return list(set(observed_transformations))

# %%
dTransformations = dict()
for i, row in ocrdf.iterrows():
    ocrtext = str(row['ocrtext'])
    humtext = str(row['humtext'])
    for t in capture_transformations(humtext, ocrtext, editops(humtext, ocrtext)):
        if t[0] in dTransformations:
            dTransformations[t[0]].append(t[1])
        else:
            dTransformations[t[0]] = [t[1]]

def sort_by_values_len(dict):
    dict_len= {key: len(value) for key, value in dict.items()}
    import operator
    sorted_key_list = sorted(dict_len.items(), key=operator.itemgetter(1), reverse=True)
    sorted_dict = [(item[0], dict[item [0]]) for item in sorted_key_list]
    return sorted_dict

sortedTransformations = sort_by_values_len(dTransformations)

# %%
for t in sortedTransformations:
    print(t[0], Counter(t[1]))
# Out:
# e Counter({'o': 24145, 'c': 5172, 'a': 598, 'i': 512, 't': 468, 'u': 422, 'r': 229, 's': 207, 'p': 191, 'n': 180, 'é': 91, 'f': 54, '»': 49, 'ó': 40, '.': 29, '«': 23, '"': 23, 'ö': 20, 'l': 18, 'B': 16, 'q': 15, '^': 14, 'è': 14, 'b': 14, 'ê': 12, 'd': 11, '-': 9, 'ç': 9, 'P': 9, 'j': 9, 'í': 8, 'L': 8, "'": 7, '*': 7, 'O': 7, 'v': 6, 'g': 5, 'k': 5, 'h': 5, 'C': 4, 'V': 4, 'ë': 3, 'm': 3, '3': 2, ';': 2, 'y': 2, 'G': 2, 'î': 2, 'á': 2, 'x': 2, 'J': 2, '?': 1, '!': 1, '6': 1, 'ß': 1, 'H': 1, 'ú': 1, 'K': 1, 'â': 1, 'û': 1, '\\': 1, '9': 1, '(': 1, 'D': 1, 'U': 1, 'F': 1, 'M': 1, 'ü': 1, 'ô': 1})
# r Counter({'i': 12553, 'l': 956, 't': 907, 'n': 60, '.': 22, 'í': 18, 'v': 17, "'": 16, 'T': 14, 'f': 13, 'u': 13, 'c': 13, '!': 12, '-': 9, 'j': 8, 'x': 8, 'o': 7, 'a': 6, 'd': 6, '»': 5, 'V': 4, 's': 3, '"': 3, 'y': 3, 'h': 3, 'e': 3, '¡': 2, 'Y': 2, '^': 2, 'ï': 2, 'O': 1, 'm': 1, '*': 1, 'w': 1, 'b': 1, 'p': 1, 'k': 1, 'B': 1, 'S': 1, ']': 1})
# a Counter({'n': 4301, 'u': 2929, 'i': 2885, 'o': 1047, 's': 311, 'e': 206, 't': 158, 'j': 56, 'l': 53, 'r': 39, '.': 37, '»': 36, 'p': 32, 'á': 28, 'd': 23, 'ä': 19, 'c': 19, 'v': 16, '&': 16, 'R': 15, '«': 15, 'h': 14, 'B': 13, '*': 13, '?': 11, 'A': 10, 'H': 9, '^': 7, '_': 6, 'â': 6, 'ó': 6, 'í': 6, 'f': 6, '"': 5, 'q': 5, 'x': 5, '-': 5, 'J': 5, "'": 4, 'k': 4, 'à': 4, 'é': 3, 'ï': 2, '3': 2, 'w': 2, 'b': 2, '\\': 2, 'U': 2, 'ú': 2, '¿': 2, 'T': 1, '8': 1, 'P': 1, 'û': 1, 'L': 1, 'S': 1, 'V': 1, 'É': 1, 'O': 1, 'ü': 1, 'g': 1, 'D': 1})
# Ma Counter({'i': 25, 'l': 4, 't': 2, 'u': 2, 'vn': 1, '-U': 1, 'î': 1, 'Ab': 1, 'c': 1, 'Vi': 1, 'Vt': 1, '2m': 1, 'Hu': 1, 'í': 1})
# rv Counter({'n': 28, 'ñ': 3, 'i': 3, 'h': 1, 'y': 1, 'R': 1, 'e': 1, 'ti': 1, 'i\\': 1, 'il': 1, 'u': 1})
# ca Counter({'e': 5, 'n': 4, 'en': 4, 'ri': 3, 'eu': 3, 's': 2, 'on': 2, 'm': 2, 'ui': 2, 'iu': 2, 'A': 1, 'os': 1, 'r': 1, 'ei': 1, 'ai': 1, 'éi': 1, '.n': 1, 'ni': 1, 'ou': 1, 'oj': 1, 'o': 1, '.i': 1})
# ...
# Ol Counter({'C': 1})
# dfi Counter({'ilD': 1})
# CONCERT Counter({'concdrt': 1})
# IAG Counter({'Aia': 1})
# IîV Counter({'R': 1})
# ani Counter({'lin': 1})
# 'f Counter({'c': 1})
# itf Counter({'llt': 1})
# Iri Counter({'iil': 1})
# 'h Counter({'s': 1})
# ILLAWARR Counter({'^': 1})
# ryba Counter({'r': 1})
# Dye Counter({'o': 1})
# nna Counter({'min': 1})
# issi Counter({'ISKf': 1})
# 'E Counter({'r': 1})
# PARK Counter({'pauk': 1})
# Îf Counter({'N': 1})
# 'B Counter({'s': 1})
# ïî Counter({'B': 1})
# tle Counter({'-': 1})
# tow Counter({'f': 1})
# .A. Counter({'t': 1})
# Iê Counter({'F': 1})
# lÍfEÍSAV Counter({'L': 1})
# LD Counter({'I': 1})
# enzi Counter({'c': 1})
# Zeala Counter({'N': 1})
# õr Counter({'rb': 1})
# Bre Counter({'Utc': 1})
# Ct Counter({'R': 1})
# Bec Counter({'Dci': 1})
# fith Counter({'lnli': 1})
# ggins Counter({'t': 1})
# Bryce Counter({'C': 1})
# -Ok Counter({'P': 1})
# tca Counter({"U'A": 1})
# Car Counter({'m': 1})
# uaife Counter({'UAIÍL': 1})
# Whit Counter({'t': 1})
# RG Counter({'KO': 1})
# ao Counter({'uu': 1})
# ompson Counter({'t': 1})
# Ind Counter({'lil': 1})
# .a Counter({'A': 1})
# jV Counter({'A': 1})
# tar Counter({'G': 1})
# Laughlin Counter({'t': 1})
# t¡ Counter({'Q': 1})
# Esthe Counter({'l': 1})
# nastasia Counter({'u': 1})
# rna Counter({'iuu': 1})
# ust Counter({'UBl': 1})
# ras Counter({'iua': 1})
# ieu Counter({'E': 1})
# tç Counter({'g': 1})
# iH Counter({'s': 1})
# ous Counter({'dUH': 1})
# -n Counter({'N': 1})
# l) Counter({'D': 1})
# enter'-I Counter({'T': 1})
# Taup Counter({'M': 1})
# gst Counter({'d': 1})
# .AV Counter({'i': 1})
# Parke Counter({'i': 1})
# tî Counter({'R': 1})
# h-' Counter({'S': 1})
# hfi Counter({'lih': 1})
# lE Counter({'R': 1})
# 1J Counter({'B': 1})
# M'C Counter({'c': 1})
# Pyr Counter({'Fre': 1})
# .h Counter({'E': 1})
# Alla Counter({'i': 1})
# Xv Counter({'N': 1})
# essider Counter({'c': 1})
# Dave Counter({'o': 1})
# l* Counter({'k': 1})
# zge Counter({'Tuo': 1})
# essher Counter({'o': 1})
# Cam Counter({'n': 1})
# Whitfel Counter({'M': 1})
# |> Counter({'p': 1})
# pso Counter({'i': 1})
# ora Counter({'t': 1})
# aX Counter({'A': 1})
# Red Counter({'I': 1})
# T5 Counter({'E': 1})
# cIn Counter({"'iu": 1})
# May Counter({'o': 1})
# Deb Counter({'A': 1})
# 1V Counter({'W': 1})
# K.I Counter({'R': 1})
# yw Counter({'vu': 1})
# ckh Counter({'oUi': 1})
# jAl Counter({'M': 1})
# Grib Counter({'M': 1})
# eC Counter({'c': 1})
# îI Counter({'N': 1})
# gel Counter({'i': 1})
# Mori Counter({'I': 1})
# arshall Counter({'n': 1})
# —Geo Counter({'r': 1})
# AVI Counter({'W': 1})
# rum Counter({'ura': 1})
# Mack Counter({'K': 1})
# Stev Counter({'J': 1})
# ipo Counter({'lop': 1})
# î' Counter({'T': 1})
# QU Counter({'OT': 1})
# PIONEER Counter({'pioneee': 1})
# lsoon Counter({'t': 1})
# Qi Counter({'C': 1})
# ZJ Counter({'N': 1})
# Hock Counter({'A': 1})
# Hazebrouc Counter({'U': 1})
# yron Counter({'j': 1})
# Nar Counter({'r': 1})
# iau Counter({'utJ': 1})
# 'Î Counter({'N': 1})
# cb Counter({'e': 1})
# G." Counter({'B': 1})
# vid Counter({'V': 1})
# }--this Counter({'y': 1})
# îil Counter({'M': 1})
# ttye Counter({'T': 1})
# mme Counter({'ino': 1})
# i,- Counter({'r': 1})
# Cf Counter({'O': 1})
# ydenham Counter({'j': 1})
# zo Counter({'m': 1})
# v.and Counter({'y': 1})
# ses Counter({'Foa': 1})
# Legisla Counter({'t': 1})
# aude.- Counter({'A': 1})
# EBRU Counter({'Bimu': 1})
# byss Counter({'DjBB': 1})
# lST Counter({'N': 1})
# hmo Counter({'lum': 1})
# tjr Counter({'G': 1})
# wer Counter({'a': 1})
# lot Counter({'q': 1})
# Eck Counter({'Lea': 1})
# Austi Counter({'M': 1})
# AQU Counter({'M': 1})
# nster Counter({'p': 1})
# tm Counter({'h': 1})
# oon Counter({'e': 1})
# JW Counter({'M': 1})
# OBE Counter({'onF': 1})
# u'sskull Counter({'n': 1})
# viga Counter({'ujri': 1})
# lto Counter({'R': 1})
# OSELEY Counter({'osblet': 1})
# Newcast Counter({'T': 1})
# Parliamen Counter({'t': 1})
# h.-Nelso Counter({'n': 1})
# UTHERLAND Counter({'uthbhland': 1})
# Cly Counter({'T': 1})
# Alba Counter({'n': 1})
# ond1J Counter({'D': 1})
# hom Counter({'oui': 1})
# Pre Counter({'c': 1})
# Id Counter({'M': 1})
# cIlw Counter({'llvv': 1})
# Bel Counter({'v': 1})
# »"wa Counter({'s': 1})
# ynch Counter({'j': 1})
# emo Counter({'r': 1})
# KE Counter({'EL': 1})
# tnf Counter({'a': 1})
# ^i Counter({'u': 1})
# Parrama Counter({'t': 1})
# usch Counter({'n': 1})
# ofO Counter({'G': 1})
# URD Counter({'nau': 1})
# Drf Counter({'T': 1})
# }-street Counter({'y': 1})
# ylord Counter({'j': 1})
# ham Counter({'l': 1})
# ARKES Counter({'aukbs': 1})
# -stre Counter({'B': 1})
# o,-1 Counter({'e': 1})
# AYi Counter({'W': 1})
# Pala Counter({'i': 1})
# lac Counter({'ble': 1})
# New^ Counter({'Z': 1})
# »t Counter({'w': 1})
# iun Counter({'m': 1})
# M.L.A Counter({'B': 1})
# rdan Counter({'i': 1})
# Tha Counter({'u': 1})
# loft Counter({'D': 1})
# ",Y Counter({'W': 1})
# V.G Counter({'O': 1})
# MY^ Counter({'C': 1})
# ni' Counter({'m': 1})
# ssa Counter({'B': 1})
# —"That Counter({'-': 1})
# G' Counter({'C': 1})
# Burr Counter({'u': 1})
# nJ Counter({'u': 1})
# OCIETY Counter({'ocintj': 1})
# Elk Counter({'lil': 1})
# Ae Counter({'g': 1})
# Die Counter({'o': 1})
# ril Counter({'n': 1})
# iä Counter({'E': 1})
# thc Counter({'B': 1})
# cto Counter({'e': 1})
# Cove Counter({'c': 1})
# vincial Counter({'x': 1})
# 2-t Counter({'T': 1})
# Ab Counter({'e': 1})
# A^ Counter({'V': 1})
# o.str Counter({'e': 1})
# Liverp Counter({'o': 1})
# EXANDER Counter({'L': 1})
# vski Counter({'x': 1})
# Feb Counter({'i': 1})
# tho'K Counter({'R': 1})
# Cathol Counter({'i': 1})
# îf Counter({'N': 1})
# iame Counter({'mnii': 1})
# Woo Counter({'i': 1})
# den.- Counter({'D': 1})
# rickett Counter({'A': 1})
# ÜJ Counter({'M': 1})
# 'Al Counter({'i': 1})
# Led Counter({'eil': 1})
# a- Counter({'z': 1})
# Ulla Counter({'F': 1})
# mals Counter({'tnia': 1})
# .I' Counter({'P': 1})
# haldean Counter({'u': 1})
# nbull Counter({'s': 1})
# arwood Counter({'u': 1})
# ««- Counter({'w': 1})
# Tari Counter({'I': 1})
# Jewelle Counter({'T': 1})
# Che Counter({'Hip': 1})
# Tyr Counter({'t': 1})
# Gibral Counter({'t': 1})
# herris Counter({'HLRRIS': 1})
# hausso Counter({'l': 1})
# lassia Counter({'t': 1})
# hau Counter({'l': 1})
# FORCES Counter({'ronces': 1})
# pf Counter({'g': 1})
# I*. Counter({'R': 1})
# _-Wayda Counter({'z': 1})
# rí Counter({'m': 1})
# ish Counter({'l': 1})
# 14 Counter({'B': 1})
# .ff Counter({'W': 1})
# servatori Counter({'R': 1})
# Constantin Counter({'T': 1})
# i» Counter({'w': 1})
# urran Counter({'m': 1})
# LLI Counter({'Ual': 1})
# GRIFFITHS Counter({'grittiths': 1})
# Executi Counter({'T': 1})
# Lk Counter({'E': 1})
# at( Counter({'G': 1})
# /B Counter({'R': 1})
# xwe Counter({'wic': 1})
# Îv Counter({'N': 1})
# zn Counter({'m': 1})
# inc Counter({'mit': 1})
# riet Counter({'y': 1})
# Hr Counter({'E': 1})
# Conci Counter({'I': 1})
# LK Counter({'U': 1})
# VAt Counter({'W': 1})
# ZI Counter({'R': 1})
# hristch Counter({'l': 1})
# rch Counter({'i': 1})
# Ban Counter({'m': 1})
# nell Counter({'u': 1})
# íf Counter({'N': 1})
# Ford Counter({'y': 1})
# Fd Counter({'tl': 1})
# Fev Counter({'e': 1})
# JVC Counter({'M': 1})
# Fath Counter({'theR': 1})
# i? Counter({'P': 1})
# mbooya Counter({'u': 1})
# hie Counter({'luo': 1})
# I» Counter({'N': 1})
# R.W.G.M Counter({'l': 1})
# By Counter({'r': 1})
# rnme Counter({'nuno': 1})
# nt^i Counter({'N': 1})
# FFI Counter({'iri': 1})
# IFFI Counter({'irri': 1})
# nnia Counter({'iinu': 1})
# serge Counter({'L': 1})
# Pit Counter({'f': 1})
# lanesian Counter({'h': 1})
# ingh Counter({'mgli': 1})
# thol Counter({'T': 1})
# rium Counter({'nuin': 1})
# Lor Counter({'l': 1})
# 13-ro Counter({'a': 1})
# uw Counter({'m\\': 1})
# ivor Counter({'I': 1})
# RALIA Counter({'l': 1})
# rchgrove Counter({'i': 1})
# ristch Counter({'u': 1})
# echi Counter({'ailu': 1})
# tt' Counter({'R': 1})
# lizabet Counter({'h': 1})
# ligh Counter({'hgli': 1})
# «'a Counter({'w': 1})
# bourne Counter({'l': 1})
# athfi Counter({'n': 1})
# Vincen Counter({'S': 1})
# TUV Counter({'R': 1})
# j'e Counter({'y': 1})
# KT. Counter({'R': 1})
# F.M. Counter({'r': 1})
# MB Counter({'F': 1})
# mil Counter({'a': 1})
# fI Counter({'T': 1})
# wke Counter({'p': 1})
# aux Counter({'IUX': 1})
# Quee Counter({'c': 1})
# o'n Counter({'e': 1})
# IGT Counter({'F': 1})
# o« Counter({'e': 1})
# kf Counter({'l': 1})
# rre Counter({'m': 1})
# Hamilto Counter({'M': 1})
# JO Counter({'jp': 1})
# ckery Counter({'i': 1})
# Vf Counter({'W': 1})
# Nt Counter({'M': 1})
# Utree Counter({'t': 1})
# Rénovat Counter({'H': 1})
# ^T Counter({'W': 1})
# tzpatrick Counter({'u': 1})
# Reyno Counter({'l': 1})
# LOUR Counter({'I': 1})
# byterian Counter({'l': 1})
# v\ Counter({'w': 1})
# mpous Counter({'t': 1})
# .-stroet Counter({'x': 1})
# rck Counter({'i': 1})
# fc' Counter({'S': 1})
# vk Counter({'il': 1})
# agh Counter({'a': 1})
# XjP Counter({'T': 1})
# ynne Counter({'j': 1})
# burg Counter({'-': 1})
# Hic Counter({'IHe': 1})
# rers Counter({'i': 1})
# incent Counter({'l': 1})
# IPS Counter({'U': 1})
# Alph Counter({'.': 1})
# ckvill Counter({'e': 1})
# chell Counter({'t': 1})
# \« Counter({'w': 1})
# ." Counter({'F': 1})
# AAi Counter({'w': 1})
# tria Counter({'f': 1})
# 'K. Counter({'E': 1})
# Elizabe Counter({'M': 1})
# abe Counter({'r': 1})
# ^A Counter({'W': 1})
# Sun Counter({'L': 1})
# FRI Counter({'fIU': 1})
# Ferry Counter({'-lane': 1})
# »in Counter({'s': 1})
# ters Counter({'n': 1})
# Infan Counter({'i': 1})
# a'n Counter({'s': 1})
# läl Counter({'E': 1})
# POLYNESI Counter({'r': 1})
# Gla Counter({'i': 1})
# rrg Counter({'nir': 1})
# Bounda Counter({'i': 1})
# Mas Counter({'Umt': 1})
# !1 Counter({'E': 1})
# Som Counter({'B': 1})
# VBi Counter({'v': 1})
# a'B Counter({'s': 1})
# wellbrook Counter({'v': 1})
# RLY Counter({'l': 1})
# Ur Counter({'u': 1})
# ja Counter({'p': 1})
# Wom Counter({'M': 1})
# Sullivan Counter({'t': 1})
# «-Maxnn Counter({'s': 1})
# Im Counter({'p': 1})
# Additi Counter({'V': 1})
# enan Counter({'t': 1})
# ,? Counter({'g': 1})
# iR Counter({'r': 1})
# Bun Counter({'Uim': 1})
# terr Counter({'S': 1})
# »-rond Counter({'y': 1})
# Windeye Counter({'M': 1})
# nins Counter({'mriK': 1})
# nT Counter({'M': 1})
# HOI.0-A Counter({'N': 1})
# Pf Counter({'F': 1})
# jS. Counter({'E': 1})
# anss Counter({'o': 1})
# atP Counter({'B': 1})
# /î Counter({'Z': 1})
# itt Counter({'W': 1})
# Tin Counter({"i'm": 1})
# L.A Counter({'M': 1})
# CUY'K Counter({'R': 1})
# Levie Counter({'I': 1})
# IÜ Counter({'E': 1})
# iri Counter({'m': 1})
# ML Counter({'a': 1})
# f» Counter({'e': 1})
# Mus Counter({'m': 1})
# Lea Counter({'lon': 1})
# Onslo Counter({'M': 1})
# rell Counter({'s': 1})
# )'e Counter({'l': 1})
# HOOD Counter({'-': 1})
# Íl Counter({'I': 1})
# r» Counter({'N': 1})
# Rig Counter({'Bur': 1})
# ï' Counter({'T': 1})
# )-Htreet Counter({'y': 1})
# iet Counter({'tol': 1})
# Fia Counter({'u': 1})
# ome Counter({'mus': 1})
# ^Y Counter({'W': 1})
# erbo Counter({'r': 1})
# atll Counter({'R': 1})
# O's Counter({'S': 1})
# cau Counter({'ees': 1})
# XJ Counter({'U': 1})
# Miner Counter({'.': 1})
# \il Counter({'L': 1})
# inna Counter({'lNNA': 1})
# èa Counter({'e': 1})
# liS. Counter({'E': 1})
# }1 Counter({'y': 1})
# -)- Counter({'s': 1})
# -J Counter({'H': 1})
# |K Counter({'p': 1})
# .(h Counter({'C': 1})
# CO Counter({'co': 1})
# TIO Counter({'rio': 1})
# ENS Counter({'Cvs': 1})
# O'F Counter({'T': 1})
# Had Counter({'mul': 1})
# cAl Counter({'i': 1})
# ér Counter({'e': 1})
# —R. Counter({'-It': 1})
# —H. Counter({'-II': 1})
# c.waa Counter({'e': 1})
# -As Counter({'O': 1})
# IheB Counter({'H': 1})
# SOUTH Counter({'sooth': 1})
# Nl Counter({'W': 1})
# Quea Counter({'n': 1})
# Ki).- Counter({'A': 1})
# Darl Counter({'i': 1})
# Rew Counter({'d': 1})
# Fitzgib Counter({'J': 1})
# hj Counter({'k': 1})
# are Counter({'o': 1})
# (J Counter({'O': 1})
# cin Counter({'ent': 1})
# )i Counter({'y': 1})
# Fish Counter({'S': 1})
# Kin Counter({'Ivm': 1})
# ^J Counter({'B': 1})
# byï Counter({'C': 1})
# tche Counter({'l': 1})
# JAC Counter({'j': 1})
# Peak Counter({'\\': 1})
# ONS Counter({'ost': 1})
# SOL Counter({'soi': 1})
# erse Counter({'o': 1})
# /O Counter({'U': 1})
# I" Counter({'P': 1})
# rli Counter({'h': 1})
# ounc Counter({'O': 1})
# rfl Counter({'m': 1})
# ebach Counter({'t': 1})
# Mudge Counter({'a': 1})
# ilyC Counter({'o': 1})
# S?? Counter({'h': 1})
# .O Counter({'C': 1})
# ssembly Counter({'t': 1})
# »,be Counter({'s': 1})
# nJf Counter({'o': 1})
# inar Counter({'g': 1})
# c*-th Counter({'e': 1})
# Barn Counter({'irii': 1})
# pst Counter({'j': 1})
# RÍ' Counter({'P': 1})
# ambing Counter({'AMBINA': 1})
# iqu Counter({'i': 1})
# RIVER Counter({'hiver': 1})
# Aust Counter({'S': 1})
# Edwa Counter({'M': 1})
# Eri Counter({'n': 1})
# Ashe Counter({'a': 1})
# 3-» Counter({'M': 1})
# Qui Counter({'I': 1})
# kr Counter({'lu': 1})
# xchange Counter({'s': 1})
# «^ Counter({'s': 1})
# "c Counter({'e': 1})
# ltj Counter({'i': 1})
# Oldf Counter({'K': 1})
# Bucki Counter({'I': 1})
# áy Counter({'a': 1})
# Newt Counter({'T': 1})
# Commiss Counter({'t': 1})
# ^a Counter({'A': 1})
# Hitche Counter({'l': 1})
# ckso Counter({'i': 1})
# Riv Counter({'Bri': 1})
# nfNow Counter({'C': 1})
# Od Counter({'I': 1})
# gton Counter({'i': 1})
# Sax Counter({'bu\\': 1})
# ilson Counter({'IISOD': 1})
# Wooll Counter({'H': 1})
# -.Geiio Counter({'r': 1})
# Pai Counter({'nla': 1})
# Kle Counter({'r': 1})
# Merc Counter({'h': 1})
# McC Counter({'O': 1})
# eon Counter({'»_o': 1})
# ph Counter({'nW': 1})
# HIT Counter({'IU1': 1})
# '1- Counter({'c': 1})
# óf Counter({'o': 1})
# Cal Counter({'d': 1})
# The Counter({'D': 1})
# nza Counter({'iiz': 1})
# üf Counter({'e': 1})
# riso Counter({'n': 1})
# v'J Counter({'y': 1})
# uta Counter({'n': 1})
# eso Counter({'n': 1})
# emi Counter({'bnu': 1})
# ziri Counter({'s': 1})
# O. Counter({'J': 1})
# C.C.Sha Counter({'M': 1})
# E.G Counter({'M': 1})
# J.H.Stewa Counter({'M': 1})
# >-Registrar Counter({'y': 1})
# tS Counter({'R': 1})
# ean Counter({'i': 1})
# 1Ï Counter({'E': 1})
# :> Counter({'o': 1})
# u| Counter({'n': 1})
# OJ Counter({'C': 1})
# gtr Counter({'ijt': 1})
# tii Counter({'m': 1})
# gians Counter({'t': 1})
# Lan Counter({'c': 1})
# uui Counter({'m': 1})
# PJ Counter({'E': 1})
# .5 Counter({'E': 1})
# Vo Counter({'l': 1})
# "X Counter({'Y': 1})
# gza Counter({'g': 1})
# HOU Counter({'T': 1})
# thel Counter({'I': 1})
# est Counter({'o': 1})
# ark Counter({'.tK': 1})
# irc Counter({'lio': 1})
# .-La Counter({'x': 1})
# rnie Counter({'r': 1})
# .-i Counter({'a': 1})
# gall Counter({'f': 1})
# RLIAMENT Counter({'B': 1})
# Ül Counter({'U': 1})
# assetter Counter({'u': 1})
# lrom Counter({'N': 1})
# His Counter({'M': 1})
# URR Counter({'üßU': 1})
# acdoug Counter({'HCUOUK': 1})
# oandE Counter({'e': 1})
# ltt Counter({'R': 1})
# Aru Counter({'m': 1})
# ZE Counter({'7L': 1})
# ÜT Counter({'U': 1})
# ï'Sl Counter({'T': 1})
# Lim Counter({'in.': 1})
# semilch Counter({'w': 1})
# mmis Counter({'raum': 1})
# Res Counter({'a': 1})
# uí Counter({'m': 1})
# hank Counter({'b': 1})
# gam Counter({'a': 1})
# Hou Counter({'tho': 1})
# S.W. Counter({'b': 1})
# tas Counter({'W': 1})
# TH Counter({'UI': 1})
# Nic Counter({'IMo': 1})
# ewis Counter({'BWIS': 1})
# Stand Counter({'fsUta': 1})
# Atta Counter({'Y': 1})
# uFire Counter({'n': 1})
# tbeói Counter({'G': 1})
# theT Counter({'F': 1})
# REPR Counter({'ÏOrE': 1})
# íS Counter({'E': 1})
# ior Counter({'n': 1})
# 'Con Counter({'Toii': 1})
# lis Counter({'hri': 1})
# Caledo Counter({'N': 1})
# »'Camp Counter({'s': 1})
# goons Counter({'r': 1})
# T^ Counter({'L': 1})
# Dr Counter({'Si': 1})
# pc Counter({'g': 1})
# ocke Counter({'n': 1})
# HH Counter({'mi': 1})
# ITFIE Counter({'irriL': 1})
# eterson Counter({'ETEHSON': 1})
# bb Counter({'ht': 1})
# t* Counter({'s': 1})
# ENTW Counter({'O': 1})
# Itl Counter({'R': 1})
# fif Counter({'M': 1})
# Gli Counter({'QIl': 1})
# tll Counter({'d': 1})
# .B Counter({'R': 1})
# nven Counter({'meii': 1})
# LT Counter({'U': 1})
# BxonHu Counter({'D': 1})
# mli Counter({'inh': 1})
# cKin Counter({"'lCm": 1})
# t> Counter({'e': 1})
# all Counter({'A': 1})
# pri Counter({'jin': 1})
# Oa Counter({'i': 1})
# u'u Counter({'n': 1})
# ons Counter({'f': 1})
# gent Counter({'i': 1})
# r' Counter({'d': 1})
# 'H Counter({'s': 1})
# Soci Counter({'sOCj': 1})
# »" Counter({'v': 1})
# A1 Counter({'M': 1})
# val Counter({'i': 1})
# ailly Counter({'r': 1})
# sso Counter({'BSO': 1})
# 'Í Counter({'c': 1})
# Vrn Counter({'R': 1})
# kreal Counter({'l': 1})
# 1-I Counter({'H': 1})
# Wentw Counter({'A': 1})
# sV Counter({'W': 1})
# Kari Counter({'I': 1})
# ylor Counter({'j': 1})
# o1 Counter({'e': 1})
# ert Counter({'cil': 1})
# ILLIAMS Counter({'llliims': 1})
# G.L Counter({'t': 1})
# s:—"O Counter({'n': 1})
# .L. Counter({'X': 1})
# JOHN Counter({'lohn': 1})
# NVr Counter({'W': 1})
# Lag Counter({'Ilt': 1})
# ias Counter({'lie': 1})
# Anglic Counter({'t': 1})
# day Counter({'iln': 1})
# XF Counter({'N': 1})
# yu Counter({')U': 1})
# lái Counter({'E': 1})
# IFI Counter({'iri': 1})
# .Vee Counter({'M': 1})
# LLAT Counter({'I': 1})
# ROWNE Counter({'eownb': 1})
# John' Counter({'M': 1})
# %' Counter({'v': 1})
# Derri Counter({'B': 1})
# swi Counter({'BWl': 1})
# H' Counter({'M': 1})
# iati Counter({'c': 1})
# Lean Counter({'l': 1})
# U' Counter({'l': 1})

# %%
true_variations = {k: list(set(g["ocrtext"].tolist())) for k,g in ocrdf.groupby("humtext")}

# %%
def create_false_variations(hum_token, dTransformations, allTransfKeys, allTransfValues):
    num_changes = random.choice([1, 1, 1, 1, 2])
    random_subst_len = random.choice([1, 2, 3])
    parts = [hum_token[i : i + random_subst_len] for i in range(0, len(hum_token), random_subst_len)]
    random.shuffle(allTransfValues)
    random.shuffle(parts)
    keep_false_variation = ""
    for n in range(num_changes):
        if parts:
            for p in parts:
                if p in dTransformations:
                    for tv in allTransfValues:
                        if len(tv) <= 3 and not tv in dTransformations[p]:
                            keep_false_variation = hum_token.replace(p, tv, 1)
                            if keep_false_variation.strip() != "":
                                break
    return keep_false_variation

# %%
transformations_keys = [transf for transf in list(dTransformations.keys()) if len(transf) <= 3]
transformations_values = [transf for transf in list(dTransformations.values())]
transformations_values = list(set([item for sublist in transformations_values for item in sublist]))

with open('ocr_posneg.tsv', mode='w') as fw:
    for hum_token in true_variations:
        for i in range(len(true_variations[hum_token])):
            truevar = true_variations[hum_token][i]
            falsevar = create_false_variations(hum_token, dTransformations, transformations_keys, transformations_values).strip()
            if truevar and falsevar:
                fw.write(hum_token.strip() + "\t" + truevar  + "\tTRUE\n")
                fw.write(hum_token.strip() + "\t" + falsevar + "\tFALSE\n")

# %%
# Since we're learning transformations at a token level, we're missing the white space in our vocabulary.

transformations_keys = [transf for transf in list(dTransformations.keys()) if len(transf) <= 3]
transformations_values = [transf for transf in list(dTransformations.values())]
transformations_values = list(set([item for sublist in transformations_values for item in sublist]))

with open('ocr_posneg_whitespaces.tsv', mode='w') as fw:
    for hum_token in true_variations:
        for i in range(len(true_variations[hum_token])):
            truevar = true_variations[hum_token][i]
            falsevar = create_false_variations(hum_token, dTransformations, transformations_keys, transformations_values).strip()
            if truevar and falsevar:
                fw.write(hum_token.strip() + "\t" + truevar  + "\tTRUE\n")
                fw.write(hum_token.strip() + "\t" + falsevar + "\tFALSE\n")
                if random.choices(population=[1, 0], weights=[0.01, 0.99])[0] == 1:
                    randomCharTrue = random.choice(truevar)
                    randomCharFalse = random.choice(falsevar)
                    truevar = truevar.replace(randomCharTrue, randomCharTrue + " ", 1)
                    falsevar = falsevar.replace(randomCharFalse, randomCharFalse + " ", 1)
                    fw.write(hum_token.strip() + "\t" + truevar  + "\tTRUE\n")
                    fw.write(hum_token.strip() + "\t" + falsevar + "\tFALSE\n")
