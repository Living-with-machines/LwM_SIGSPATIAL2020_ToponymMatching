# %% [markdown]
# ### Process WikiGazetteer
#
# WikiGazetteer is a gazetteer based on Wikipedia and enriched with Geonames data.
#
# To build a WikiGazetteer (into a MySQL database) for a specific Wikipedia version follow [these instructions](https://github.com/Living-with-machines/lwm_GIR19_resolving_places/tree/master/gazetteer_construction).
#
# This notebook takes the relevant fields in the WikiGazetteer MySQL database and creates a more manageable pickle file.

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-

import mysql.connector
from mysql.connector import Error
import pandas as pd

# %%
def wikigazExtract(language, dbname):
    # Access wikigazetteer database
    gazDB = ""
    cursorGaz = ""
    try:
        gazDB = mysql.connector.connect(
                host='localhost',
                database=dbname,
                user='testGazetteer',
                password='1234')
        if gazDB.is_connected():
            cursorGaz = gazDB.cursor(dictionary=True)
    except Error as e:
        print("Error while connecting to MySQL", e)

    # Query database
    cursorGaz.execute("""
            select altname.altname, location.wiki_title, location.lat, location.lon, altname.source, location.type, location.page_len from altname
            join location on location.id=altname.main_id
            where altname.source IN ('wikimain', 'geonamesmain', 'geonamesascii', 'geonamesalt', 'wikiredirect')
            and LENGTH(altname) < 30
        """)
    results = cursorGaz.fetchall()

    # Store relevant metadata into pkl
    name = []
    wikititle = []
    latitude = []
    longitude = []
    source = []
    loctype = []
    pagelen = []
    for x in results:
        altname = x['altname']
        name.append(x['altname'])
        wikititle.append(x['wiki_title'])
        latitude.append(x['lat'])
        longitude.append(x['lon'])
        source.append(x['source'])
        loctype.append(x['type'])
        pagelen.append(x['page_len'])
    wg = pd.DataFrame()
    wg["name"] = name
    wg["wikititle"] = wikititle
    wg["latitude"] = latitude
    wg["longitude"] = longitude
    wg["source"] = source
    wg["loctype"] = loctype
    wg["pagelen"] = pagelen
    wg.to_pickle("../../../resources/wikiGaz_" + language + "_basic.pkl")

    # Close connection to gazDB
    if (gazDB.is_connected()):
        cursorGaz.close()
        gazDB.close()

# %%
wikigazExtract("en", "wikiGazetteer")
wikigazExtract("es", "wikiGazES")
wikigazExtract("el", "wikiGazEL")

# %% [markdown]
# #### Explore resulting gazetteers

# %%
wges = pd.read_pickle("../../../resources/wikiGaz_en_basic.pkl")

# %%
wges[wges["name"] == "Barcelona"]
# Out:
#               name                                         wikititle  \
# 61435    Barcelona                               Barcelona,_Arkansas
# 152751   Barcelona                              Blooming_Grove,_Ohio
# 391252   Barcelona                    Barcelona,_Rio_Grande_do_Norte
# 496148   Barcelona  Barcelona_(Parliament_of_Catalonia_constituency)
# 542288   Barcelona                               Barcelona,_Cornwall
# 617597   Barcelona     Barcelona_(Congress_of_Deputies_constituency)
# 1478146  Barcelona                                         Barcelona
# 1506863  Barcelona                             Province_of_Barcelona
# 1578593  Barcelona                              Barcelona,_Venezuela
# 1591196  Barcelona                               Barcelona,_Sorsogon
# 1856887  Barcelona                                   Barcelona_Light
#
#          latitude  longitude        source   loctype  pagelen
# 61435    35.62060  -94.45610      wikimain      city      927
# 152751   40.70780  -82.71670   geonamesalt      city     2863
# 391252   -5.93333  -35.93330      wikimain      city     4941
# 496148   41.45000    2.08333      wikimain      None    90111
# 542288   50.35520   -4.50470      wikimain      None     2841
# 617597   41.45000    2.08333      wikimain      None   108024
# 1478146  41.38330    2.18333      wikimain      city   158048
# 1506863  41.45000    2.08333   geonamesalt    adm2nd     6523
# 1578593  10.11670  -64.71670      wikimain      city    27014
# 1591196  12.87000  124.13000      wikimain      None    10035
# 1856887  42.34080  -79.59500  wikiredirect  landmark     8106

# %%
wges[wges["wikititle"] == "Barcelona"]
# Out:
#                              name  wikititle  latitude  longitude  \
# 1478146                 Barcelona  Barcelona   41.3833    2.18333
# 1478147                   Barcino  Barcelona   41.3833    2.18333
# 1478148                Bartzelona  Barcelona   41.3833    2.18333
# 1478149                 Barzelona  Barcelona   41.3833    2.18333
# 1478150                 Barcelono  Barcelona   41.3833    2.18333
# 1478151                 Barcelone  Barcelona   41.3833    2.18333
# 1478152                 Barselóna  Barcelona   41.3833    2.18333
# 1478153                Barcellona  Barcelona   41.3833    2.18333
# 1478154                 Barselona  Barcelona   41.3833    2.18333
# 1478155                Barcillona  Barcelona   41.3833    2.18333
# 1478156      Lungsod ng Barcelona  Barcelona   41.3833    2.18333
# 1478157          la Ciudad Condal  Barcelona   41.3833    2.18333
# 1478158                 Barcelůna  Barcelona   41.3833    2.18333
# 1478159                 Barcełona  Barcelona   41.3833    2.18333
# 1478160              Barçellonn-a  Barcelona   41.3833    2.18333
# 1478161                Barċellona  Barcelona   41.3833    2.18333
# 1478162                Barseloana  Barcelona   41.3833    2.18333
# 1478163               Bartzellona  Barcelona   41.3833    2.18333
# 1478164                 Barsélona  Barcelona   41.3833    2.18333
# 1478165                Barseluona  Barcelona   41.3833    2.18333
# 1478166                 Barseluna  Barcelona   41.3833    2.18333
# 1478167                 Barslon-a  Barcelona   41.3833    2.18333
# 1478168                  Barselon  Barcelona   41.3833    2.18333
# 1706269      Capital of Catalonia  Barcelona   41.3833    2.18333
# 1711827            Barcelona City  Barcelona   41.3833    2.18333
# 1711830         City of Barcelona  Barcelona   41.3833    2.18333
# 1727140      Second city of Spain  Barcelona   41.3833    2.18333
# 1901534  The weather in Barcelona  Barcelona   41.3833    2.18333
# 2139234                Barcelonan  Barcelona   41.3833    2.18333
# 2162163    Geography of Barcelona  Barcelona   41.3833    2.18333
#
#                source loctype  pagelen
# 1478146      wikimain    city   158048
# 1478147   geonamesalt    city   158048
# 1478148   geonamesalt    city   158048
# 1478149   geonamesalt    city   158048
# 1478150   geonamesalt    city   158048
# 1478151   geonamesalt    city   158048
# 1478152   geonamesalt    city   158048
# 1478153   geonamesalt    city   158048
# 1478154   geonamesalt    city   158048
# 1478155   geonamesalt    city   158048
# 1478156   geonamesalt    city   158048
# 1478157   geonamesalt    city   158048
# 1478158   geonamesalt    city   158048
# 1478159   geonamesalt    city   158048
# 1478160   geonamesalt    city   158048
# 1478161   geonamesalt    city   158048
# 1478162   geonamesalt    city   158048
# 1478163   geonamesalt    city   158048
# 1478164   geonamesalt    city   158048
# 1478165   geonamesalt    city   158048
# 1478166   geonamesalt    city   158048
# 1478167   geonamesalt    city   158048
# 1478168   geonamesalt    city   158048
# 1706269  wikiredirect    city   158048
# 1711827  wikiredirect    city   158048
# 1711830  wikiredirect    city   158048
# 1727140  wikiredirect    city   158048
# 1901534  wikiredirect    city   158048
# 2139234  wikiredirect    city   158048
# 2162163  wikiredirect    city   158048

# %%
wges.shape
# Out:
# (2401260, 7)

# %%
wges.name.unique().shape[0]
# Out:
# 2104201

# %%
wges.wikititle.unique().shape[0]
# Out:
# 1087620

# %%
wges.source.unique()
# Out:
# array(['wikimain', 'geonamesalt', 'geonamesmain', 'geonamesascii',
#        'wikiredirect'], dtype=object)
