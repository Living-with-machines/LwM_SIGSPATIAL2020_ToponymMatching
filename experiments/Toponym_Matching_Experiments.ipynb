# %% [markdown]
# # Toponym Matching experiments

# %%
from DeezyMatch import train as dm_train
from DeezyMatch import plot_log
from DeezyMatch import finetune as dm_finetune
from DeezyMatch import inference as dm_inference

from pathlib import Path
from shutil import copyfile

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Evaluation of Toponym Matching methods on different datasets (table 5)

# %% [markdown]
# ### 1. Dataset: wikigaz_en

# %%
if not Path('./models/wikigaz_en_hlayers_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_trainval.txt",
             model_name="wikigaz_en_hlayers_001")

# %%
# plot log file
plot_log(path2log="./models/wikigaz_en_hlayers_001/log.txt", 
         output_name="wikigaz_en_hlayers_001")
# Out:
# output_name: wikigaz_en_hlayers_001
# Time: 4995s
# output_name: wikigaz_en_hlayers_001
# Time / epoch: 555.000s
# ...
# Epoch: 6, Loss: 0.16
# Epoch: 6, macro F1: 0.938
# Epoch: 6, Acc: 0.938
# Epoch: 6, Prec/Recall: 0.938/0.938

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00006"

# %%
copyfile("./models/wikigaz_en_hlayers_001/" + best_checkpoint + ".model", "./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model")
copyfile("./models/wikigaz_en_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model_state_dict")
# Out:
# './models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_en_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_test.txt",
             pretrained_model_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model",
             pretrained_vocab_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.vocab")
# Out:
# 2020-09-09 08:03:07 lwm-embeddings [INFO] read input file: ./models/wikigaz_en_hlayers_001/input_dfm.yaml
# 2020-09-09 08:03:07 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 08:03:07 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 08:03:07 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_en_test.txt
# 2020-09-09 08:03:08 lwm-embeddings [INFO] number of labels, True: 33469 and False: 33469
# length s1:   0%|          | 0/66938 [00:00<?, ?it/s]
# 2020-09-09 08:03:08 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 08:10:14 lwm-embeddings [INFO] 09/09/2020_08:10:14 -- Epoch: 0/0; Test; loss: 0.154; acc: 0.940; precision: 0.941, recall: 0.938, macrof1: 0.940, weightedf1: 0.940
# --- 427.00263381004333 seconds ---

# %% [markdown]
# ### 2. Dataset: wikigaz_es

# %%
if not Path('./models/wikigaz_es_hlayers_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_es_trainval.txt",
             model_name="wikigaz_es_hlayers_001")
# Out:
# 2020-09-09 08:18:06 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 08:18:06 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 08:18:06 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 08:18:06 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets_definitive/wikigaz_es_trainval.txt
# 2020-09-09 08:18:07 lwm-embeddings [INFO] number of labels, True: 68412 and False: 68412
# 2020-09-09 08:18:07 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 08:18:07 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.1208498477935791
# 2020-09-09 08:18:07 lwm-embeddings [INFO] splits are as follow:
# train    95776
# val      41046
# test         2
# Name: split, dtype: int64
# 2020-09-09 08:18:07 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 08:18:07 lwm-embeddings [INFO] -- create vocabulary
# ...

# %%
# plot log file
plot_log(path2log="./models/wikigaz_es_hlayers_001/log.txt", 
         output_name="wikigaz_es_hlayers_001")
# Out:
# output_name: wikigaz_es_hlayers_001
# Time: 5906s
# output_name: wikigaz_es_hlayers_001
# Time / epoch: 656.222s
# ...
# Epoch: 5, Loss: 0.211
# Epoch: 5, macro F1: 0.923
# Epoch: 5, Acc: 0.923
# Epoch: 5, Prec/Recall: 0.919/0.927

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00005"

# %%
copyfile("./models/wikigaz_es_hlayers_001/" + best_checkpoint + ".model", "./models/wikigaz_es_hlayers_001/wikigaz_es_hlayers_001.model")
copyfile("./models/wikigaz_es_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_es_hlayers_001/wikigaz_es_hlayers_001.model_state_dict")
# Out:
# './models/wikigaz_es_hlayers_001/wikigaz_es_hlayers_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_es_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_es_test.txt",
             pretrained_model_path="./models/wikigaz_es_hlayers_001/wikigaz_es_hlayers_001.model",
             pretrained_vocab_path="./models/wikigaz_es_hlayers_001/wikigaz_es_hlayers_001.vocab")
# Out:
# 2020-09-09 10:12:06 lwm-embeddings [INFO] read input file: ./models/wikigaz_es_hlayers_001/input_dfm.yaml
# 2020-09-09 10:12:06 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 10:12:06 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 10:12:06 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_es_test.txt
# 2020-09-09 10:12:06 lwm-embeddings [INFO] number of labels, True: 7601 and False: 7601
# s2 padding:   0%|          | 0/15202 [00:00<?, ?it/s]
# 2020-09-09 10:12:06 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 10:12:21 lwm-embeddings [INFO] 09/09/2020_10:12:21 -- Epoch: 0/0; Test; loss: 0.220; acc: 0.918; precision: 0.915, recall: 0.923, macrof1: 0.918, weightedf1: 0.918
# --- 14.427034616470337 seconds ---

# %% [markdown]
# ### 3. Dataset: wikigaz_el

# %%
if not Path('./models/wikigaz_el_hlayers_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_el_trainval.txt",
             model_name="wikigaz_el_hlayers_001")
# Out:
# s2 padding:   0%|          | 0/832 [00:00<?, ?it/s]
# 2020-09-09 10:13:58 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 10:13:58 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 10:13:58 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 10:13:58 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_el_trainval.txt
# 2020-09-09 10:13:58 lwm-embeddings [INFO] number of labels, True: 1389 and False: 1389
# 2020-09-09 10:13:58 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 10:13:58 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.01687765121459961
# 2020-09-09 10:13:58 lwm-embeddings [INFO] splits are as follow:
# train    1944
# val       832
# test        2
# Name: split, dtype: int64
# 2020-09-09 10:13:58 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 10:13:58 lwm-embeddings [INFO] -- create vocabulary
# ...

# %%
# plot log file
plot_log(path2log="./models/wikigaz_el_hlayers_001/log.txt", 
         output_name="wikigaz_el_hlayers_001")
# Out:
# output_name: wikigaz_el_hlayers_001
# Time: 98s
# output_name: wikigaz_el_hlayers_001
# Time / epoch: 10.889s
# ...
# Epoch: 5, Loss: 0.338
# Epoch: 5, macro F1: 0.859
# Epoch: 5, Acc: 0.859
# Epoch: 5, Prec/Recall: 0.829/0.906

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00005"

# %%
copyfile("./models/wikigaz_el_hlayers_001/" + best_checkpoint + ".model", "./models/wikigaz_el_hlayers_001/wikigaz_el_hlayers_001.model")
copyfile("./models/wikigaz_el_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_el_hlayers_001/wikigaz_el_hlayers_001.model_state_dict")
# Out:
# './models/wikigaz_el_hlayers_001/wikigaz_el_hlayers_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_el_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_el_test.txt",
             pretrained_model_path="./models/wikigaz_el_hlayers_001/wikigaz_el_hlayers_001.model",
             pretrained_vocab_path="./models/wikigaz_el_hlayers_001/wikigaz_el_hlayers_001.vocab")
# Out:
# 2020-09-09 10:16:03 lwm-embeddings [INFO] read input file: ./models/wikigaz_el_hlayers_001/input_dfm.yaml
# 2020-09-09 10:16:03 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 10:16:03 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 10:16:03 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_el_test.txt
# 2020-09-09 10:16:03 lwm-embeddings [INFO] number of labels, True: 154 and False: 154
# 2020-09-09 10:16:03 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 10:16:03 lwm-embeddings [INFO] 09/09/2020_10:16:03 -- Epoch: 0/0; Test; loss: 0.357; acc: 0.857; precision: 0.820, recall: 0.916, macrof1: 0.857, weightedf1: 0.857
# --- 0.41327762603759766 seconds ---

# %% [markdown]
# ### 4. Dataset: ocr

# %%
if not Path('./models/ocr_hlayers_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_trainval.txt",
             model_name="ocr_hlayers_001")
# Out:
# 2020-09-09 10:18:29 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 10:18:29 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 10:18:29 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 10:18:29 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_trainval.txt
# 2020-09-09 10:18:30 lwm-embeddings [INFO] number of labels, True: 42301 and False: 42302
# 2020-09-09 10:18:30 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 10:18:30 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.08092546463012695
# 2020-09-09 10:18:30 lwm-embeddings [INFO] splits are as follow:
# train    59221
# val      25380
# test         2
# Name: split, dtype: int64
# 2020-09-09 10:18:30 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 10:18:30 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-09 10:18:31 lwm-embeddings [INFO] -- convert tokens to indices
# ...

# %%
# plot log file
plot_log(path2log="./models/ocr_hlayers_001/log.txt", 
         output_name="ocr_hlayers_001")
# Out:
# output_name: ocr_hlayers_001
# Time: 3451s
# output_name: ocr_hlayers_001
# Time / epoch: 383.444s
# ...
# Epoch: 4, Loss: 0.122
# Epoch: 4, macro F1: 0.958
# Epoch: 4, Acc: 0.958
# Epoch: 4, Prec/Recall: 0.941/0.978

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00004"

# %%
copyfile("./models/ocr_hlayers_001/" + best_checkpoint + ".model", "./models/ocr_hlayers_001/ocr_hlayers_001.model")
copyfile("./models/ocr_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/ocr_hlayers_001/ocr_hlayers_001.model_state_dict")
# Out:
# './models/ocr_hlayers_001/ocr_hlayers_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/ocr_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_test.txt",
             pretrained_model_path="./models/ocr_hlayers_001/ocr_hlayers_001.model",
             pretrained_vocab_path="./models/ocr_hlayers_001/ocr_hlayers_001.vocab")
# Out:
# 2020-09-09 11:22:49 lwm-embeddings [INFO] read input file: ./models/ocr_hlayers_001/input_dfm.yaml
# 2020-09-09 11:22:49 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 11:22:49 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 11:22:49 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_test.txt
# 2020-09-09 11:22:49 lwm-embeddings [INFO] number of labels, True: 4254 and False: 4254
# 2020-09-09 11:22:49 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 11:22:57 lwm-embeddings [INFO] 09/09/2020_11:22:57 -- Epoch: 0/0; Test; loss: 0.127; acc: 0.958; precision: 0.944, recall: 0.973, macrof1: 0.958, weightedf1: 0.958
# --- 8.003621816635132 seconds ---

# %% [markdown]
# ### 5. Dataset: santos

# %%
if not Path('./models/santos_hlayers_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/santos_trainval.txt",
             model_name="santos_hlayers_001")
# Out:
# s2 padding:   0%|          | 0/832 [00:00<?, ?it/s]
# 2020-09-09 10:13:58 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 10:13:58 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 10:13:58 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 10:13:58 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_el_trainval.txt
# 2020-09-09 10:13:58 lwm-embeddings [INFO] number of labels, True: 1389 and False: 1389
# 2020-09-09 10:13:58 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 10:13:58 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.01687765121459961
# 2020-09-09 10:13:58 lwm-embeddings [INFO] splits are as follow:
# train    1944
# val       832
# test        2
# Name: split, dtype: int64
# 2020-09-09 10:13:58 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 10:13:58 lwm-embeddings [INFO] -- create vocabulary
# ...

# %%
# plot log file
plot_log(path2log="./models/santos_hlayers_001/log.txt", 
         output_name="santos_hlayers_001")
# Out:
# output_name: wikigaz_el_hlayers_001
# Time: 98s
# output_name: wikigaz_el_hlayers_001
# Time / epoch: 10.889s
# ...
# Epoch: 5, Loss: 0.338
# Epoch: 5, macro F1: 0.859
# Epoch: 5, Acc: 0.859
# Epoch: 5, Prec/Recall: 0.829/0.906

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = ""

# %%
copyfile("./models/santos_hlayers_001/" + best_checkpoint + ".model", "./models/santos_hlayers_001/santos_hlayers_001.model")
copyfile("./models/santos_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/santos_hlayers_001/santos_hlayers_001.model_state_dict")

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/santos_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/santos_test.txt",
             pretrained_model_path="./models/santos_hlayers_001/santos_hlayers_001.model",
             pretrained_vocab_path="./models/santos_hlayers_001/santos_hlayers_001.vocab")

# %% [markdown]
# ### 6. Dataset: OCR (fine-tuned over wikigaz_en_hlayers_v001 with all rows)

# %%
# fine-tune a pretrained model stored at pretrained_model_path and pretrained_vocab_path 
dm_finetune(input_file_path="./inputs/input_dfm.yaml", 
            dataset_path="../datasets/toponym_matching_datasets/ocr_trainval.txt", 
            model_name="finetuned_ocr_hlayers_001",
            pretrained_model_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model", 
            pretrained_vocab_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.vocab")
# Out:
# 2020-09-09 12:39:13 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 12:39:13 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 12:39:13 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 12:39:13 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_trainval.txt
# 2020-09-09 12:39:13 lwm-embeddings [INFO] number of labels, True: 42301 and False: 42302
# 2020-09-09 12:39:13 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 12:39:13 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.0737762451171875
# 2020-09-09 12:39:13 lwm-embeddings [INFO] splits are as follow:
# train    59221
# val      25380
# test         2
# Name: split, dtype: int64
# 2020-09-09 12:39:13 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 12:39:14 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-09 12:39:15 lwm-embeddings [INFO] -- convert tokens to indices
# ...

# %%
# plot log file
plot_log(path2log="./models/finetuned_ocr_hlayers_001/log.txt", 
         output_name="finetuned_ocr_hlayers_001")
# Out:
# output_name: finetuned_ocr_hlayers_001
# Time: 897s
# output_name: finetuned_ocr_hlayers_001
# Time / epoch: 99.667s
# ...
# Epoch: 4, Loss: 0.238
# Epoch: 4, macro F1: 0.909
# Epoch: 4, Acc: 0.909
# Epoch: 4, Prec/Recall: 0.886/0.938

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00004"

# %%
copyfile("./models/finetuned_ocr_hlayers_001/" + best_checkpoint + ".model", "./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.model")
copyfile("./models/finetuned_ocr_hlayers_001/" + best_checkpoint + ".model_state_dict", "./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.model_state_dict")
# Out:
# './models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/finetuned_ocr_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_test.txt",
             pretrained_model_path="./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.model",
             pretrained_vocab_path="./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.vocab")
# Out:
# s1 padding:   0%|          | 0/8508 [00:00<?, ?it/s]
# 2020-09-09 12:55:54 lwm-embeddings [INFO] read input file: ./models/finetuned_ocr_hlayers_001/input_dfm.yaml
# 2020-09-09 12:55:54 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 12:55:54 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 12:55:54 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_test.txt
# 2020-09-09 12:55:54 lwm-embeddings [INFO] number of labels, True: 4254 and False: 4254
# 2020-09-09 12:55:55 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 12:56:02 lwm-embeddings [INFO] 09/09/2020_12:56:02 -- Epoch: 0/0; Test; loss: 0.237; acc: 0.907; precision: 0.883, recall: 0.939, macrof1: 0.907, weightedf1: 0.907
# --- 8.029255867004395 seconds ---

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/finetuned_ocr_hlayers_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_test.txt",
             pretrained_model_path="./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.model",
             pretrained_vocab_path="./models/finetuned_ocr_hlayers_001/finetuned_ocr_hlayers_001.vocab")
# Out:
# 2020-09-09 12:56:02 lwm-embeddings [INFO] read input file: ./models/finetuned_ocr_hlayers_001/input_dfm.yaml
# 2020-09-09 12:56:02 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 12:56:02 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 12:56:02 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_en_test.txt
# 2020-09-09 12:56:03 lwm-embeddings [INFO] number of labels, True: 33469 and False: 33469
# length s1:   0%|          | 0/66938 [00:00<?, ?it/s]
# 2020-09-09 12:56:04 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 12:57:19 lwm-embeddings [INFO] 09/09/2020_12:57:19 -- Epoch: 0/0; Test; loss: 1.291; acc: 0.705; precision: 0.729, recall: 0.653, macrof1: 0.704, weightedf1: 0.704
# --- 76.09203314781189 seconds ---

# %% [markdown]
# ### 7. Dataset: OCR (fine-tuned over wikigaz_en_hlayers_v001: 8000 rows)

# %%
# fine-tune a pretrained model stored at pretrained_model_path and pretrained_vocab_path 
dm_finetune(input_file_path="./inputs/input_dfm.yaml", 
            dataset_path="../datasets/toponym_matching_datasets/ocr_trainval.txt", 
            model_name="finetuned_ocr_hlayers_002",
            pretrained_model_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.model", 
            pretrained_vocab_path="./models/wikigaz_en_hlayers_001/wikigaz_en_hlayers_001.vocab",
            n_train_examples=8000)
# Out:
# 2020-09-09 12:57:19 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-09 12:57:19 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 12:57:19 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 12:57:19 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_trainval.txt
# 2020-09-09 12:57:19 lwm-embeddings [INFO] number of labels, True: 42301 and False: 42302
# 2020-09-09 12:57:19 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-09 12:57:19 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.06352829933166504
# 2020-09-09 12:57:19 lwm-embeddings [INFO] splits are as follow:
# not_assigned    51221
# val             25380
# train            8000
# test                2
# Name: split, dtype: int64
# 2020-09-09 12:57:19 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-09 12:57:19 lwm-embeddings [INFO] -- create vocabulary
# ...

# %%
# plot log file
plot_log(path2log="./models/finetuned_ocr_hlayers_002/log.txt", 
         output_name="finetuned_ocr_hlayers_002")
# Out:
# output_name: finetuned_ocr_hlayers_002
# Time: 302s
# output_name: finetuned_ocr_hlayers_002
# Time / epoch: 33.556s
# ...
# Epoch: 7, Loss: 0.372
# Epoch: 7, macro F1: 0.852
# Epoch: 7, Acc: 0.852
# Epoch: 7, Prec/Recall: 0.851/0.852

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00007"

# %%
copyfile("./models/finetuned_ocr_hlayers_002/" + best_checkpoint + ".model", "./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.model")
copyfile("./models/finetuned_ocr_hlayers_002/" + best_checkpoint + ".model_state_dict", "./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.model_state_dict")
# Out:
# './models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/finetuned_ocr_hlayers_002/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_test.txt",
             pretrained_model_path="./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.model",
             pretrained_vocab_path="./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.vocab")
# Out:
# s1 padding:   0%|          | 0/8508 [00:00<?, ?it/s]
# 2020-09-09 13:29:09 lwm-embeddings [INFO] read input file: ./models/finetuned_ocr_hlayers_002/input_dfm.yaml
# 2020-09-09 13:29:09 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 13:29:09 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 13:29:09 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_test.txt
# 2020-09-09 13:29:09 lwm-embeddings [INFO] number of labels, True: 4254 and False: 4254
# 2020-09-09 13:29:09 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 13:29:16 lwm-embeddings [INFO] 09/09/2020_13:29:16 -- Epoch: 0/0; Test; loss: 0.371; acc: 0.849; precision: 0.850, recall: 0.847, macrof1: 0.849, weightedf1: 0.849
# --- 7.047617197036743 seconds ---

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/finetuned_ocr_hlayers_002/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_test.txt",
             pretrained_model_path="./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.model",
             pretrained_vocab_path="./models/finetuned_ocr_hlayers_002/finetuned_ocr_hlayers_002.vocab")
# Out:
# 2020-09-09 13:29:16 lwm-embeddings [INFO] read input file: ./models/finetuned_ocr_hlayers_002/input_dfm.yaml
# 2020-09-09 13:29:16 lwm-embeddings [INFO] GPU was requested but not available.
# 2020-09-09 13:29:16 lwm-embeddings [INFO] pytorch will use: cpu
# 2020-09-09 13:29:16 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_en_test.txt
# 2020-09-09 13:29:17 lwm-embeddings [INFO] number of labels, True: 33469 and False: 33469
# length s1:   0%|          | 0/66938 [00:00<?, ?it/s]
# 2020-09-09 13:29:17 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-09 13:30:26 lwm-embeddings [INFO] 09/09/2020_13:30:26 -- Epoch: 0/0; Test; loss: 0.932; acc: 0.747; precision: 0.790, recall: 0.673, macrof1: 0.746, weightedf1: 0.746
# --- 70.11840867996216 seconds ---
