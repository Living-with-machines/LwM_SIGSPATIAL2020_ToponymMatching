# %% [markdown]
# # Toponym Matching experiments

# %%
from DeezyMatch import train as dm_train
from DeezyMatch import plot_log
from DeezyMatch import finetune as dm_finetune
from DeezyMatch import inference as dm_inference

from pathlib import Path
from shutil import copyfile

# %% [markdown]
# ## Evaluation of Toponym Matching methods on different datasets (table 5)

# %% [markdown]
# ### 1. Dataset: wikigaz_en

# %%
if not Path('./models/wikigaz_en_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_trainval.txt",
             model_name="wikigaz_en_001")
# Out:
# 2020-09-16 09:41:21 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-16 09:41:21 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 09:41:21 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_en_trainval.txt
# 2020-09-16 09:41:26 lwm-embeddings [INFO] number of labels, True: 301219 and False: 301219
# 2020-09-16 09:41:26 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-16 09:41:26 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.5189287662506104
# 2020-09-16 09:41:26 lwm-embeddings [INFO] splits are as follow:
# train    421706
# val      180730
# test          2
# Name: split, dtype: int64
# 2020-09-16 09:41:26 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-16 09:41:27 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-16 09:41:35 lwm-embeddings [INFO] -- convert tokens to indices
# ...

# %%
# plot log file
plot_log(path2log="./models/wikigaz_en_001/log.txt", 
         output_name="wikigaz_en_001")
# Out:
# output_name: wikigaz_en_001
# Time: 1680s
# output_name: wikigaz_en_001
# Time / epoch: 560.000s
# ...
# Epoch: 3, Loss: 0.158
# Epoch: 3, macro F1: 0.935
# Epoch: 3, Acc: 0.935
# Epoch: 3, Prec/Recall: 0.946/0.921

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00003"

# %%
copyfile("./models/wikigaz_en_001/" + best_checkpoint + ".model", "./models/wikigaz_en_001/wikigaz_en_001.model")
copyfile("./models/wikigaz_en_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_en_001/wikigaz_en_001.model_state_dict")
# Out:
# './models/wikigaz_en_001/wikigaz_en_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_en_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_en_test.txt",
             pretrained_model_path="./models/wikigaz_en_001/wikigaz_en_001.model",
             pretrained_vocab_path="./models/wikigaz_en_001/wikigaz_en_001.vocab")
# Out:
# 2020-09-16 10:30:22 lwm-embeddings [INFO] read input file: ./models/wikigaz_en_001/input_dfm.yaml
# 2020-09-16 10:30:22 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:30:22 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_en_test.txt
# 2020-09-16 10:30:22 lwm-embeddings [INFO] number of labels, True: 33469 and False: 33469
# length s2:   0%|          | 0/66938 [00:00<?, ?it/s]
# 2020-09-16 10:30:22 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-16 10:30:49 lwm-embeddings [INFO] 09/16/2020_10:30:49 -- Epoch: 0/0; Test; loss: 0.156; acc: 0.936; precision: 0.948, recall: 0.923, macrof1: 0.936, weightedf1: 0.936
# --- 27.56799077987671 seconds ---

# %% [markdown]
# ### 2. Dataset: wikigaz_es

# %%
if not Path('./models/wikigaz_es_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_es_trainval.txt",
             model_name="wikigaz_es_001")
# Out:
# 2020-09-16 10:30:55 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-16 10:30:55 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:30:55 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_es_trainval.txt
# 2020-09-16 10:30:56 lwm-embeddings [INFO] number of labels, True: 68412 and False: 68412
# 2020-09-16 10:30:56 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-16 10:30:56 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.09631109237670898
# 2020-09-16 10:30:56 lwm-embeddings [INFO] splits are as follow:
# train    95776
# val      41046
# test         2
# Name: split, dtype: int64
# 2020-09-16 10:30:56 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-16 10:30:56 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-16 10:30:58 lwm-embeddings [INFO] -- convert tokens to indices
# ...

# %%
# plot log file
plot_log(path2log="./models/wikigaz_es_001/log.txt", 
         output_name="wikigaz_es_001")
# Out:
# output_name: wikigaz_es_001
# Time: 499s
# output_name: wikigaz_es_001
# Time / epoch: 124.750s
# ...
# Epoch: 4, Loss: 0.194
# Epoch: 4, macro F1: 0.922
# Epoch: 4, Acc: 0.922
# Epoch: 4, Prec/Recall: 0.939/0.902

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00004"

# %%
copyfile("./models/wikigaz_es_001/" + best_checkpoint + ".model", "./models/wikigaz_es_001/wikigaz_es_001.model")
copyfile("./models/wikigaz_es_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_es_001/wikigaz_es_001.model_state_dict")
# Out:
# './models/wikigaz_es_001/wikigaz_es_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_es_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_es_test.txt",
             pretrained_model_path="./models/wikigaz_es_001/wikigaz_es_001.model",
             pretrained_vocab_path="./models/wikigaz_es_001/wikigaz_es_001.vocab")
# Out:
# 2020-09-16 10:43:18 lwm-embeddings [INFO] read input file: ./models/wikigaz_es_001/input_dfm.yaml
# 2020-09-16 10:43:18 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:43:18 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_es_test.txt
# 2020-09-16 10:43:19 lwm-embeddings [INFO] number of labels, True: 7601 and False: 7601
# 2020-09-16 10:43:19 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-16 10:43:25 lwm-embeddings [INFO] 09/16/2020_10:43:25 -- Epoch: 0/0; Test; loss: 0.197; acc: 0.922; precision: 0.940, recall: 0.901, macrof1: 0.922, weightedf1: 0.922
# --- 6.40136456489563 seconds ---

# %% [markdown]
# ### 3. Dataset: wikigaz_el

# %%
if not Path('./models/wikigaz_el_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_el_trainval.txt",
             model_name="wikigaz_el_001")
# Out:
# 2020-09-16 10:43:39 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-16 10:43:39 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:43:39 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_el_trainval.txt
# 2020-09-16 10:43:39 lwm-embeddings [INFO] number of labels, True: 1389 and False: 1389
# 2020-09-16 10:43:39 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-16 10:43:39 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.014986991882324219
# 2020-09-16 10:43:39 lwm-embeddings [INFO] splits are as follow:
# train    1944
# val       832
# test        2
# Name: split, dtype: int64
# 2020-09-16 10:43:39 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-16 10:43:39 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-16 10:43:39 lwm-embeddings [INFO] -- convert tokens to indices
# ...

# %%
# plot log file
plot_log(path2log="./models/wikigaz_el_001/log.txt", 
         output_name="wikigaz_el_001")
# Out:
# output_name: wikigaz_el_001
# Time: 9s
# output_name: wikigaz_el_001
# Time / epoch: 2.250s
# ...
# Epoch: 4, Loss: 0.344
# Epoch: 4, macro F1: 0.842
# Epoch: 4, Acc: 0.843
# Epoch: 4, Prec/Recall: 0.804/0.906

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00004"

# %%
copyfile("./models/wikigaz_el_001/" + best_checkpoint + ".model", "./models/wikigaz_el_001/wikigaz_el_001.model")
copyfile("./models/wikigaz_el_001/" + best_checkpoint + ".model_state_dict", "./models/wikigaz_el_001/wikigaz_el_001.model_state_dict")
# Out:
# './models/wikigaz_el_001/wikigaz_el_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/wikigaz_el_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/wikigaz_el_test.txt",
             pretrained_model_path="./models/wikigaz_el_001/wikigaz_el_001.model",
             pretrained_vocab_path="./models/wikigaz_el_001/wikigaz_el_001.vocab")
# Out:
# 2020-09-16 10:44:24 lwm-embeddings [INFO] read input file: ./models/wikigaz_el_001/input_dfm.yaml
# 2020-09-16 10:44:24 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:44:24 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/wikigaz_el_test.txt
# 2020-09-16 10:44:24 lwm-embeddings [INFO] number of labels, True: 154 and False: 154
# 2020-09-16 10:44:24 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-16 10:44:25 lwm-embeddings [INFO] 09/16/2020_10:44:25 -- Epoch: 0/0; Test; loss: 0.330; acc: 0.841; precision: 0.793, recall: 0.922, macrof1: 0.840, weightedf1: 0.840
# --- 0.19110774993896484 seconds ---

# %% [markdown]
# ### 4. Dataset: ocr

# %%
if not Path('./models/ocr_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_trainval.txt",
             model_name="ocr_001")
# Out:
# 2020-09-16 10:44:46 lwm-embeddings [INFO] read input file: ./inputs/input_dfm.yaml
# 2020-09-16 10:44:46 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 10:44:46 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_trainval.txt
# 2020-09-16 10:44:47 lwm-embeddings [INFO] number of labels, True: 42301 and False: 42302
# 2020-09-16 10:44:47 lwm-embeddings [INFO] Splitting the Dataset
# 2020-09-16 10:44:47 lwm-embeddings [INFO] finish splitting the Dataset. User time: 0.05431723594665527
# 2020-09-16 10:44:47 lwm-embeddings [INFO] splits are as follow:
# train    59221
# val      25380
# test         2
# Name: split, dtype: int64
# 2020-09-16 10:44:47 lwm-embeddings [INFO] start creating a lookup table and convert characters to indices
# 2020-09-16 10:44:47 lwm-embeddings [INFO] -- create vocabulary
# 2020-09-16 10:44:48 lwm-embeddings [INFO] -- convert tokens to indices
# 2020-09-16 10:44:48 lwm-embeddings [INFO] -- create a lookup table for tokens
# ...

# %%
# plot log file
plot_log(path2log="./models/ocr_001/log.txt", 
         output_name="ocr_001")
# Out:
# output_name: ocr_001
# Time: 189s
# output_name: ocr_001
# Time / epoch: 63.000s
# ...
# Epoch: 3, Loss: 0.136
# Epoch: 3, macro F1: 0.951
# Epoch: 3, Acc: 0.951
# Epoch: 3, Prec/Recall: 0.941/0.962

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00003"

# %%
copyfile("./models/ocr_001/" + best_checkpoint + ".model", "./models/ocr_001/ocr_001.model")
copyfile("./models/ocr_001/" + best_checkpoint + ".model_state_dict", "./models/ocr_001/ocr_001.model_state_dict")
# Out:
# './models/ocr_001/ocr_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/ocr_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/ocr_test.txt",
             pretrained_model_path="./models/ocr_001/ocr_001.model",
             pretrained_vocab_path="./models/ocr_001/ocr_001.vocab")
# Out:
# s1 padding:   0%|          | 0/8508 [00:00<?, ?it/s]
# 2020-09-16 11:06:05 lwm-embeddings [INFO] read input file: ./models/ocr_001/input_dfm.yaml
# 2020-09-16 11:06:05 lwm-embeddings [INFO] pytorch will use: cuda
# 2020-09-16 11:06:05 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/ocr_test.txt
# 2020-09-16 11:06:05 lwm-embeddings [INFO] number of labels, True: 4254 and False: 4254
# 2020-09-16 11:06:05 lwm-embeddings [INFO] skipping 0 lines
# ...
# 2020-09-16 11:06:08 lwm-embeddings [INFO] 09/16/2020_11:06:08 -- Epoch: 0/0; Test; loss: 0.133; acc: 0.953; precision: 0.948, recall: 0.959, macrof1: 0.953, weightedf1: 0.953
# --- 3.0404045581817627 seconds ---

# %% [markdown]
# ### 5. Dataset: santos

# %%
if not Path('./models/santos_001').is_dir():
    # train a new model
    dm_train(input_file_path="./inputs/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/santos_trainval.txt",
             model_name="santos_001")

# %%
# plot log file
plot_log(path2log="./models/santos_001/log.txt", 
         output_name="santos_001")
# Out:
# output_name: santos_001
# Time: 31770s
# output_name: santos_001
# Time / epoch: 4538.571s
# ...
# Epoch: 6, Loss: 0.265
# Epoch: 6, macro F1: 0.894
# Epoch: 6, Acc: 0.894
# Epoch: 6, Prec/Recall: 0.896/0.891

# %% [markdown]
# **!!! WARNING:** copy best checkpoint model to final model

# %%
best_checkpoint = "checkpoint00006"

# %%
copyfile("./models/santos_001/" + best_checkpoint + ".model", "./models/santos_001/santos_001.model")
copyfile("./models/santos_001/" + best_checkpoint + ".model_state_dict", "./models/santos_001/santos_001.model_state_dict")
# Out:
# './models/santos_001/santos_001.model_state_dict'

# %%
# model inference using a model stored at pretrained_model_path and pretrained_vocab_path 
dm_inference(input_file_path="./models/santos_001/input_dfm.yaml",
             dataset_path="../datasets/toponym_matching_datasets/santos_test.txt",
             pretrained_model_path="./models/santos_001/santos_001.model",
             pretrained_vocab_path="./models/santos_001/santos_001.vocab")
# Out:
# 2020-09-16 11:08:48 lwm-embeddings [INFO] read input file: ./models/santos_001/input_dfm.yaml
# 2020-09-16 11:08:48 lwm-embeddings [INFO] pytorch will use: cuda:1
# /data/anaconda/envs/py37torch/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'DeezyMatch.rnn_networks.two_parallel_rnns' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# 2020-09-16 11:08:49 lwm-embeddings [INFO] read CSV file: ../datasets/toponym_matching_datasets/santos_test.txt
# 2020-09-16 11:08:53 lwm-embeddings [INFO] number of labels, True: 216872 and False: 216872
# 2020-09-16 11:08:57 lwm-embeddings [INFO] skipping 0 lines
# ...
